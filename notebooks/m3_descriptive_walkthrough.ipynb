# %% [markdown]
# # Milestone 3 Walkthrough
#
# This notebook is a lightweight walkthrough for Milestone 3 descriptive EDA artifacts generated by scripts/m3_descriptive_eda.py.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
TABLE_DIR = ROOT / 'outputs' / 'tables'
FIG_DIR = ROOT / 'reports' / 'assets' / 'figures'

TABLE_DIR, FIG_DIR

# %%
monthly_rev = pd.read_csv(TABLE_DIR / 'm3_monthly_revenue_table.csv')
order_mix = pd.read_csv(TABLE_DIR / 'm3_order_source_mix.csv')
return_rate = pd.read_csv(TABLE_DIR / 'm3_return_rate_by_category.csv')

display(monthly_rev.head())
display(order_mix.head())
display(return_rate.head())

# %%
sorted([p.name for p in FIG_DIR.glob('m3_*.png')])
